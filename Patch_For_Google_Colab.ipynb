# %% [markdown]
# # Building CPK untuk game Yuru Camp : Have a Nice Day! Bahasa Indonesia

# %%
#@title Install Bahan
# !sudo dpkg --add-architecture i386
# !sudo mkdir -pm755 /etc/apt/keyrings
# !sudo wget -O /etc/apt/keyrings/winehq-archive.key https://dl.winehq.org/wine-builds/winehq.key
# !sudo wget -NP /etc/apt/sources.list.d/ https://dl.winehq.org/wine-builds/ubuntu/dists/jammy/winehq-jammy.sources
# !sudo apt update
# !sudo apt upgrade
# !sudo apt install --install-recommends wine-stable
# !sudo apt install wine-stable winetricks
# !wget http://dl.winehq.org/wine/wine-gecko/2.47.1/wine-gecko-2.47.1-x86.msi
# !wine msiexec /i wine-gecko-2.47.1-x86.msi
# !rm wine-gecko-2.47.1-x86.msi
# !wget https://dl.winehq.org/wine/wine-mono/9.1.0/wine-mono-9.1.0-x86.msi
# !wine start wine-mono-9.1.0-x86.msi
# !rm wine-mono-9.1.0-x86.msi
# !pip install UnityPy
# !pip install p_tqdm
# !git clone https://github.com/StevenBeach33/YC_Indonesia.git
# !wget https://github.com/SciresM/hactool/releases/download/1.4.0/hactool-1.4.0-win.zip
# !unzip hactool-1.4.0-win.zip -d YC_Indonesia/3rdparty/
# !rm hactool-1.4.0-win.zip

# %%
#@title Build CPK
# !bash YC_Indonesia/repack_scrpt.cpk.sh

# %% [markdown]
# # Untuk terjemahan UI dan lainnya, anda harus meng-upload file game original yang anda miliki.

# %%
#@title Upload File Game dengan nama "yurucamp.nsp"
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('File berhasil di-upload'.format(
      name=fn, length=len(uploaded[fn])))

# %%
#@title Upload Keys
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('Keys berhasil di-upload'.format(
      name=fn, length=len(uploaded[fn])))

# %%
#@title Ekstrak nca from nsp
# !wine /content/YC_Indonesia/3rdparty/hactool.exe --keyset /content/prod.keys yurucamp.nsp --pfs0dir=YC_Indonesia/work -t pfs0

# %%
#@title Get titlekey from tik files
# !xxd -ps -s0x180 -l16 YC_Indonesia/work/0100d12014fc2000000000000000000b.tik

# %%
#@title Ubah xxx dengan output cell sebelumnya

# !wine /content/YC_Indonesia/3rdparty/hactool.exe --keyset /content/prod.keys -x YC_Indonesia/work/97105c79474118d294c8808a22f39bd3.nca --titlekey=xxxxxxxxxx --romfsdir=YC_Indonesia/work

# %%
#@title Patch UI
# !python3 YC_Indonesia/monobehaviour_of_borg.py

# %%
#@title Buat zip
# !zip -r out.zip YC_Indonesia/out

# %% [markdown]
# # Setelah selesai, Download file out.zip dengan cara mengklik baris 3 dipojok kiri atas dan pilih tampilkan browser file. Lalu klik titik 3 pada file out.zip dan klik Download.
